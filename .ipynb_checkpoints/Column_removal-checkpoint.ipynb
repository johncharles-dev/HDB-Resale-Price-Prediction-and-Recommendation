# %%
import pandas as pd
df = pd.read_csv('Downloaded datasets/singapore_all_pois.csv')

columns_to_drop = ['brand', 'address', 'website','phone']
df2 = df.drop(columns=columns_to_drop, errors='ignore')
df2.to_csv('singapore_all_poi_column_removed.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('datasets ready for cleaning/Hawker_Centres.csv')


columns_to_keep = ['latitude', 'longitude', 'NAME','STATUS']  

df2 = df[df.columns.intersection(columns_to_keep)]

df2.to_csv('Hawker_Centers_column_removed.csv', index=False)
