# %%
import pandas as pd
df = pd.read_csv('01_Original_datasets/singapore_malls_pois.csv')

columns_to_drop = ['name', 'lat', 'lan','phone']
df2 = df.drop(columns=columns_to_drop, errors='ignore')
df2.to_csv('Malls_datasets.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('01_Original_datasets/singapore_malls_pois.csv')


columns_to_keep = ['name', 'lat', 'lon']  

df2 = df[df.columns.intersection(columns_to_keep)]

df2.to_csv('Malls_datasets.csv', index=False)
