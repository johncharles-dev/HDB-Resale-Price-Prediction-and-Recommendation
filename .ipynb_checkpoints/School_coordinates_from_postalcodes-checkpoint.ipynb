# %%
import pandas as pd
import requests
import time

def get_coordinates_from_postal(postal_code):
    url = f"https://www.onemap.gov.sg/api/common/elastic/search?searchVal={postal_code}&returnGeom=Y&getAddrDetails=Y"
    
    try:
        response = requests.get(url)
        data = response.json()
        
        if data['found'] > 0:
            result = data['results'][0]
            return float(result['LATITUDE']), float(result['LONGITUDE']), result['ADDRESS']
        else:
            return None, None, 'Not found'
    except Exception as e:
        print(f"Error for {postal_code}: {e}")
        return None, None, 'Error'

# Read CSV file
df = pd.read_csv('Downloaded datasets/Schools.csv')

# Show first few rows to verify
print("First few rows:")
print(df.head())
print("\n")

# Get coordinates for each postal code
latitudes = []
longitudes = []
addresses = []

total = len(df)
for i, postal in enumerate(df['postal_code'], 1):
    print(f"Processing {i}/{total}: {postal}")
    lat, lon, addr = get_coordinates_from_postal(postal)
    latitudes.append(lat)
    longitudes.append(lon)
    addresses.append(addr)
    time.sleep(0.1)

# Add new columns
df['latitude'] = latitudes
df['longitude'] = longitudes
df['address'] = addresses

# Save results
df.to_csv('Schools_with_coordinates.csv', index=False)
print(f"\nSuccessfully geocoded: {df['latitude'].notna().sum()} out of {total}")
# Out:
# First few rows:
#                       school_name                            url_address  \
# 0        ADMIRALTY PRIMARY SCHOOL       https://admiraltypri.moe.edu.sg/
# 1      ADMIRALTY SECONDARY SCHOOL     http://www.admiraltysec.moe.edu.sg
# 2    AHMAD IBRAHIM PRIMARY SCHOOL  http://www.ahmadibrahimpri.moe.edu.sg
# 3  AHMAD IBRAHIM SECONDARY SCHOOL  http://www.ahmadibrahimsec.moe.edu.sg
# 4                  AI TONG SCHOOL           http://www.aitong.moe.edu.sg
#
#                     address  postal_code telephone_no telephone_no_2  \
# 0    11 WOODLANDS CIRCLE          738907     63620598             na
# 1  31 WOODLANDS CRESCENT          737916     63651733       63654596
# 2    10 YISHUN STREET 11          768643     67592906             na
# 3    751 YISHUN AVENUE 7          768928     67585384             na
# 4  100 Bright Hill Drive          579646     64547672             na
#
#      fax_no fax_no_2            email_address                  mrt_desc  ...  \
# 0  63627512       na  ADMIRALTY_PS@MOE.EDU.SG         Admiralty Station  ...
# 1  63652774       na  Admiralty_SS@moe.edu.sg             ADMIRALTY MRT  ...
# 2  67592927       na          AIPS@MOE.EDU.SG                    Yishun  ...
# 3  67557778       na          AISS@MOE.EDU.SG  CANBERRA MRT, YISHUN MRT  ...
# 4  64532726       na    AITONG_SCH@MOE.EDU.SG                Bishan MRT  ...
#
#     nature_code    session_code     mainlevel_code sap_ind autonomous_ind  \
# 0  CO-ED SCHOOL        FULL DAY            PRIMARY      No             No
# 1  CO-ED SCHOOL  SINGLE SESSION  SECONDARY (S1-S5)      No             No
# 2  CO-ED SCHOOL  SINGLE SESSION            PRIMARY      No             No
# 3  CO-ED SCHOOL  SINGLE SESSION  SECONDARY (S1-S5)      No             No
# 4  CO-ED SCHOOL  SINGLE SESSION            PRIMARY     Yes             No
#
#   gifted_ind ip_ind mothertongue1_code mothertongue2_code mothertongue3_code
# 0         No     No            CHINESE              MALAY              TAMIL
# 1         No     No            CHINESE              MALAY              TAMIL
# 2         No     No            CHINESE              MALAY              TAMIL
# 3         No     No            CHINESE              MALAY              TAMIL
# 4         No     No            CHINESE                 na                 na
#
# [5 rows x 31 columns]
#
#
# Processing 1/337: 738907
# Processing 258/337: 689762
# Processing 259/337: 737758
# Processing 260/337: 544799
# Processing 261/337: 529593
# Processing 262/337: 359337
# Processing 263/337: 359342
# Processing 264/337: 357691
# Processing 265/337: 469701
# Processing 266/337: 469700
# Processing 267/337: 659401
# Processing 268/337: 556742
# Processing 269/337: 556140
# Processing 270/337: 529706
# Processing 271/337: 528986
# Processing 272/337: 308274
# Processing 273/337: 309331
# Processing 274/337: 228197
# Processing 275/337: 259240
# Processing 276/337: 689143
# Processing 277/337: 429058
# Processing 278/337: 455789
# Processing 279/337: 659322
# Processing 280/337: 518799
# Processing 281/337: 529565
# Processing 282/337: 529426
# Processing 283/337: 529427
# Processing 284/337: 439272
# Processing 285/337: 437259
# Processing 286/337: 438796
# Processing 287/337: 449761
# Processing 288/337: 569299
# Processing 289/337: 688261
# Processing 290/337: 479239
# Processing 291/337: 529564
# Processing 292/337: 469300
# Processing 293/337: 465561
# Processing 294/337: 569730
# Processing 295/337: 449035
# Processing 296/337: 448880
# Processing 297/337: 828802
# Processing 298/337: 757702
# Processing 299/337: 649223
# Processing 300/337: 679946
# Processing 301/337: 677737
# Processing 302/337: 677742
# Processing 303/337: 649188
# Processing 304/337: 648350
# Processing 305/337: 519075
# Processing 306/337: 579747
# Processing 307/337: 738079
# Processing 308/337: 738990
# Processing 309/337: 738853
# Processing 310/337: 738240
# Processing 311/337: 739062
# Processing 312/337: 739111
# Processing 313/337: 538882
# Processing 314/337: 649036
# Processing 315/337: 538784
# Processing 316/337: 538789
# Processing 317/337: 768611
# Processing 318/337: 556108
# Processing 319/337: 689100
# Processing 320/337: 538720
# Processing 321/337: 569868
# Processing 322/337: 768675
# Processing 323/337: 768679
# Processing 324/337: 768516
# Processing 325/337: 768610
# Processing 326/337: 469623
# Processing 327/337: 618654
# Processing 328/337: 609558
# Processing 329/337: 649406
# Processing 330/337: 529393
# Processing 331/337: 828676
# Processing 332/337: 538884
# Processing 333/337: 169485
# Processing 334/337: 679002
# Processing 335/337: 679962
# Processing 336/337: 556095
# Processing 337/337: 556123
#
# Successfully geocoded: 333 out of 337

# %%
df1 = pd.read_csv('Schools_with_coordinates.csv')
columns_to_drop = ['url_address', 'address', 'telephone_no', 'telephone_no_2', 
                   'fax_no', 'fax_no_2', 'email_address', 'mrt_desc', 
                   'nature_code', 'session_code', 'sap_ind', 'autonomous_ind', 
                   'gifted_ind', 'ip_ind', 'mothertongue1_code', 
                   'mothertongue2_code', 'mothertongue3_code']
df1 = df1.drop(columns=columns_to_drop, errors='ignore')
print(df1)
# Out:
#                         school_name  postal_code  \
# 0          ADMIRALTY PRIMARY SCHOOL       738907
# 1        ADMIRALTY SECONDARY SCHOOL       737916
# 2      AHMAD IBRAHIM PRIMARY SCHOOL       768643
# 3    AHMAD IBRAHIM SECONDARY SCHOOL       768928
# 4                    AI TONG SCHOOL       579646
# ..                              ...          ...
# 332          ZHANGDE PRIMARY SCHOOL       169485
# 333         ZHENGHUA PRIMARY SCHOOL       679002
# 334       ZHENGHUA SECONDARY SCHOOL       679962
# 335         ZHONGHUA PRIMARY SCHOOL       556095
# 336       ZHONGHUA SECONDARY SCHOOL       556123
#
#                                               bus_desc  \
# 0                                   TIBS 965, 964, 913
# 1                                                  904
# 2    Yishun Ring Road - 812 (white plate); Yishun A...
# 3    117, 167, 169, 800, 811, 812, 883, 856, 858, 8...
# 4                                         410, 162, 52
# ..                                                 ...
# 332  16,33,63,123,195,605,851,14,65,147,167,196,197...
# 333                      190, 184, 187, 700, 700A, 921
# 334                                      920, 922, 976
# 335  Boundary Road: 22,24,53,105,156,315,853,501,50...
# 336  22, 43, 45, 53, 58, 70, 81, 82, 100, 101, 103,...
#
#                      principal_name                           first_vp_name  \
# 0                   MR CHEN ZHONGYI                     MADAM CHUA MUI LING
# 1                      MR TAN KELLY                  MR CHAN YEW REN EUGENE
# 2                    MS BAEY EE-LYN                      MADAM YEO SIAU YEN
# 3                   MR GOH SOON HOE                        MISS LEA SHU HUI
# 4                  MR WONG JIA WANG                         MR YAK BENG WEI
# ..                              ...                                     ...
# 332              MADAM RITA RAJ LAL                           MRS LIM PEGGY
# 333  MADAM WONG HIAN HWEE CONSTANCE               MR YANG PECK CHIONG TOMMY
# 334                 MR NG HOCK SOON                MADAM TAN PEI LEE ELAINE
# 335                MRS CHAN LE CHIN  MADAM THAM SIEW LENG MRS TAN SIEW LENG
# 336                 MR TAN KIM KOON        MR SHAHUL HAMEED S/O KUTHUBUDEEN
#
#                       second_vp_name                  third_vp_name  \
# 0               MR HAMRI BIN A JALIL                             na
# 1          MR TAN HOCK CHUAN MICHAEL                             na
# 2                  MADAM ZHANG JUNLI                             na
# 3               MR QUEK CHOON HSIONG  MISS LATIFAH BTE ABDUL LATIFF
# 4            MR CHIU SHEK MAN PHILIP             MR KHOO THIAM HUAT
# ..                               ...                            ...
# 332            MR CHAN CHEONG CHEONG               MADAM WOO LI SAN
# 333  MISS SANTHANA MARY D/O POOBALAN              MADAM SNG YEE YEE
# 334           MR SAMUEL LIM KOK BOON                  MISS HE AIFEN
# 335           MRS TRINA POOK SIM NAR                             na
# 336                    MS TEO CELINE                             na
#
#     fourth_vp_name fifth_vp_name sixth_vp_name       dgp_code zone_code  \
# 0               na            na            na      WOODLANDS     NORTH
# 1               na            na            na      WOODLANDS     NORTH
# 2               na            na            na         YISHUN     NORTH
# 3               na            na            na         YISHUN     NORTH
# 4               na            na            na         BISHAN     SOUTH
# ..             ...           ...           ...            ...       ...
# 332             na            na            na    BUKIT MERAH     SOUTH
# 333             na            na            na  BUKIT PANJANG      WEST
# 334             na            na            na  BUKIT PANJANG      WEST
# 335             na            na            na      SERANGOON     SOUTH
# 336             na            na            na      SERANGOON     SOUTH
#
#                 type_code     mainlevel_code  latitude   longitude
# 0       GOVERNMENT SCHOOL            PRIMARY  1.442635  103.800040
# 1       GOVERNMENT SCHOOL  SECONDARY (S1-S5)  1.445891  103.802398
# 2       GOVERNMENT SCHOOL            PRIMARY  1.433153  103.832942
# 3       GOVERNMENT SCHOOL  SECONDARY (S1-S5)  1.436060  103.829719
# 4    GOVERNMENT-AIDED SCH            PRIMARY  1.360583  103.833020
# ..                    ...                ...       ...         ...
# 332     GOVERNMENT SCHOOL            PRIMARY  1.284212  103.825952
# 333     GOVERNMENT SCHOOL            PRIMARY  1.379429  103.769703
# 334     GOVERNMENT SCHOOL  SECONDARY (S1-S5)  1.388366  103.765511
# 335     GOVERNMENT SCHOOL            PRIMARY  1.360261  103.869713
# 336     GOVERNMENT SCHOOL  SECONDARY (S1-S5)  1.348407  103.869430
#
# [337 rows x 16 columns]
