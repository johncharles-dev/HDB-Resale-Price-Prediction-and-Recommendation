# %%
import pandas as pd

df = pd.read_csv('datasets ready for cleaning/school_column_removed.csv')

# %%
print (df.head())
# Out:
#                       school_name  postal_code     mainlevel_code  latitude  \
# 0        ADMIRALTY PRIMARY SCHOOL       738907            PRIMARY  1.442635
# 1      ADMIRALTY SECONDARY SCHOOL       737916  SECONDARY (S1-S5)  1.445891
# 2    AHMAD IBRAHIM PRIMARY SCHOOL       768643            PRIMARY  1.433153
# 3  AHMAD IBRAHIM SECONDARY SCHOOL       768928  SECONDARY (S1-S5)  1.436060
# 4                  AI TONG SCHOOL       579646            PRIMARY  1.360583
#
#     longitude
# 0  103.800040
# 1  103.802398
# 2  103.832942
# 3  103.829719
# 4  103.833020

# %%
keyword = 'PRIMARY'
column_name = 'mainlevel_code'

# %%
filtered_df = df[df[column_name].str.contains(keyword, na=False)]

# %%
print(filtered_df)
# Out:
#                       school_name                            url_address  \
# 0        ADMIRALTY PRIMARY SCHOOL       https://admiraltypri.moe.edu.sg/
# 2    AHMAD IBRAHIM PRIMARY SCHOOL  http://www.ahmadibrahimpri.moe.edu.sg
# 4                  AI TONG SCHOOL           http://www.aitong.moe.edu.sg
# 5        ALEXANDRA PRIMARY SCHOOL         http://alexandrapri.moe.edu.sg
# 6     ANCHOR GREEN PRIMARY SCHOOL   http://www.anchorgreenpri.moe.edu.sg
# ..                            ...                                    ...
# 327          YUHUA PRIMARY SCHOOL         http://www.yuhuapri.moe.edu.sg
# 329          YUMIN PRIMARY SCHOOL         http://www.yuminpri.moe.edu.sg
# 332        ZHANGDE PRIMARY SCHOOL      http://www.zhangdepri.moe.edu.sg/
# 333       ZHENGHUA PRIMARY SCHOOL      http://www.zhenghuapri.moe.edu.sg
# 335       ZHONGHUA PRIMARY SCHOOL      http://www.zhonghuapri.moe.edu.sg
#
#                            address  postal_code telephone_no telephone_no_2  \
# ...

# %%
filterde_df.to_csv('Primary_schools')
