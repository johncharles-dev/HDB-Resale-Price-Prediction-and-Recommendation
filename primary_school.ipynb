# %%
import pandas as pd

df = pd.read_csv('02_datasets ready for cleaning/school_column_removed.csv')

# %%
print (df.head())
# Out:
#                       school_name  postal_code     mainlevel_code  latitude  \
# 0        ADMIRALTY PRIMARY SCHOOL       738907            PRIMARY  1.442635
# 1      ADMIRALTY SECONDARY SCHOOL       737916  SECONDARY (S1-S5)  1.445891
# 2    AHMAD IBRAHIM PRIMARY SCHOOL       768643            PRIMARY  1.433153
# 3  AHMAD IBRAHIM SECONDARY SCHOOL       768928  SECONDARY (S1-S5)  1.436060
# 4                  AI TONG SCHOOL       579646            PRIMARY  1.360583
#
#     longitude
# 0  103.800040
# 1  103.802398
# 2  103.832942
# 3  103.829719
# 4  103.833020

# %%
keyword = 'PRIMARY'
column_name = 'mainlevel_code'

# %%
filtered_df = df[df[column_name].str.contains(keyword, na=False)]

# %%
print(filtered_df)
# Out:
#                       school_name  postal_code mainlevel_code  latitude  \
# 0        ADMIRALTY PRIMARY SCHOOL       738907        PRIMARY  1.442635
# 2    AHMAD IBRAHIM PRIMARY SCHOOL       768643        PRIMARY  1.433153
# 4                  AI TONG SCHOOL       579646        PRIMARY  1.360583
# 5        ALEXANDRA PRIMARY SCHOOL       159016        PRIMARY  1.291334
# 6     ANCHOR GREEN PRIMARY SCHOOL       544969        PRIMARY  1.390370
# ..                            ...          ...            ...       ...
# 327          YUHUA PRIMARY SCHOOL       609558        PRIMARY  1.342920
# 329          YUMIN PRIMARY SCHOOL       529393        PRIMARY  1.351316
# 332        ZHANGDE PRIMARY SCHOOL       169485        PRIMARY  1.284212
# 333       ZHENGHUA PRIMARY SCHOOL       679002        PRIMARY  1.379429
# 335       ZHONGHUA PRIMARY SCHOOL       556095        PRIMARY  1.360261
#
#       longitude
# 0    103.800040
# 2    103.832942
# 4    103.833020
# 5    103.824425
# ...

# %%
filtered_df.to_csv('Primary_school_dataset.csv')
